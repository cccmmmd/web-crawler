# %%
from urllib.request import urlopen, Request 
from bs4 import BeautifulSoup
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
url = "https://www.ptt.cc/bbs/movie/M.1704383635.A.5DE.html"

r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
resp = urlopen(r)
html = BeautifulSoup(resp)
print(html.text)
# Out:
# [無雷] 難看又無趣的金手指 - 看板 movie - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 movie
# 關於我們
# 聯絡資訊
#
#
#
#
# 返回看板
#
#
#
#
# 作者generalfungi (香菇將軍)看板movie標題[無雷] 難看又無趣的金手指時間Thu Jan  4 23:53:50 2024
#
# 優點：
#
# 梁朝偉的演技非常好
#
# 場布很厲害，好幾幕的佈景非常金碧輝煌，真正見識到什麼叫做真土豪，有大開眼界到
#
#
# 缺點：
#
# 浪費一大堆大咖演員，尤其是劉德華不知道在幹什麼，不能說演不好，就毫無亮點的表演，換成任何一位八點檔演員都可以
#
# 想模仿華爾街之狼，但主軸不明確，節奏緩慢又無聊，中間插了一些奇奇怪怪的人
#
# 結局了無心意，應該又受到了上面的審查
#
# 真的是蠻難看的一部片
#
#
# 評分：5.7/10
#
# 還有阿sa怎麼那麼大！？
#
#
#
#
#
# -----
# Sent from JPTT on my Google Pixel 6a.
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 223.136.81.13 (臺灣)
# ※ 文章網址: https://www.ptt.cc/bbs/movie/M.1704383635.A.5DE.html
# 推 zakijudelo  : 大什麼大，圖勒 01/05 00:00
# 推 wang7752    : = =??蝦??模仿?? 你知道是真實事件改編的嗎 01/05 00:10
# → wang7752    : 會插那麼多人 就事實上真的超多人涉入 01/05 00:11
# 推 rockrock1127: 真實事件但已經改編了 故事應該可以講得更精彩... 01/05 00:26
# 推 wang7752    : 其實改編的幅度不大 01/05 00:51
# 推 DATION      : 沒圖說個雞巴 01/05 01:18
# 推 mirac1e     : 這片場景美術都沒話說 有有回到那個八零年代 01/05 01:36
# → mirac1e     : 但就是少了點港味 01/05 01:36
# → mirac1e     : 結局又是那一套邪不勝正 不過這也沒辦法 01/05 01:36
# → mirac1e     : 不過這年代還可以看到這些30年老戲骨同台 01/05 01:36
# → mirac1e     : 其實已經夠了 蠻意外太保戲份算蠻多的 01/05 01:36
# → mirac1e     : 阿Sa那麼大真的意外 只看過阿嬌的 XD 01/05 01:36
# 推 eknbz       : 看到這篇和推文想進場了... 01/05 02:54
# 推 lovemykiki  : 真實故事的結局真的沒坐幾年牢啊 01/05 03:03
# 推 negotiates  : 急著去投案不就1997 懂得都懂 01/05 05:13
# 推 newman302   : 阿sa 電影裡是墊假胸啊，她都跟媒體承認了 01/05 06:21
# 推 JeNeToiLe   : 拖了這麼多年 結果沒判多久 01/05 07:14
# 推 h2owaters   : 有興趣的可去看Will會員影片的佳寧案 01/05 07:29
# 推 kuso2005    : 我覺得是一部可以順順看下去電影 不會覺得浪費錢 01/05 08:15
# → K01PTT      : 看演員名單，不管好不好看，花個23百的票錢值得啦 01/05 08:23
# → LondonHot   : 哪裡大？沒圖說個雞巴 01/05 09:44
# → longkiss0618: 審查下的港片 已沒有看的價值 01/05 10:36
# → w2776803    : 影廳八成滿 01/05 11:21
# 推 blake7899   : 你特別說有人很大會害我想去看啊 01/05 11:21
# 推 PCC2003     : 墊出來的，不用特別去看了 01/05 11:23
# 推 sfzerox     : 案件牽扯的東西太多 可能拍成影集會好一點 01/05 11:36
# 推 louis5265   : 她在神探二就有大了 01/05 11:49
# 推 wang7752    : 很多ytb都有討論過 01/05 11:56
# 推 dingading   : 真假 01/05 12:30
# 推 icexfox     : 哪裡大 01/05 13:37
# 推 kinple      : 阿 Sa的大是劇組特別幫他做的 XD 01/05 14:23
# 推 koae50      : 大是CG吧 01/05 14:59
# 推 hp4935      : 電影沒說但看訪談人設就是要靠身材，胸特地有妝造， 01/05 15:16
# → hp4935      : 本人不大XD 01/05 15:16
# → hp4935      : 她40了還是有娃娃臉，其中幾個造型也蠻美的 01/05 15:16
# 推 DarrenD     : 港片已死 不需要上電影院浪費時間 看串流即可 01/05 15:49
# → Dean99      : 看了預告超想去看的耶，梁朝偉的眼神超有戲 01/05 16:00
# → Dean99      : 完全是因為梁朝偉去看的 01/05 16:01
# 噓 QooBY       : 結局超難看 收得有夠爛 01/05 18:00
# → QooBY       : 不過阿sa的原型也是這麼正嗎 01/05 18:03
# 推 wang7752    : 阿結局原本就是這樣啊 XD 01/05 19:08
# 推 zeumax      : 也沒啥邪不勝正，主謀就判3年，而且原型故事一樣 01/05 19:30
# → zeumax      : 其他從犯死的死逃的也死，但主謀還爽，畢竟原型就爽 01/05 19:33
# → zeumax      : 翻天，電影可能真沒把爽感拍出來 01/05 19:33
# 推 wang7752    : 就那時候很多人都牽涉其中 01/05 19:44
# 推 naniyo      : 想做華麗的部分轉太硬反而看起來很尬，結局又草草 01/05 19:55
# → naniyo      : 收尾 01/05 19:55
# → naniyo      : 題材明明不錯但沒用更好的畫面呈現後面靠口白塞 01/05 19:57
# 推 wang7752    : 奇怪 為啥一堆人說草草收為~~ 圓形故事就是如此阿XD 01/05 20:38
# 推 nellykk     : 蛤~沒看到大sa 01/05 20:47
# 推 mirac1e     : 這片幾乎就是照史實演 其實劇情真的很無趣 01/05 20:53
# → mirac1e     : 不過光靠梁朝偉一個人就可以撐住整片 01/05 20:53
# → mirac1e     : 沒梁朝偉的話 這部大概就跟追龍差不多等級 01/05 20:53
# 推 bagaalo     : 應該沒有風再起時難看吧 01/05 21:51
# 推 alex0973    : 阿sa那個角色的原型胸部也很大嗎? 還是說胸部墊大 01/05 23:36
# → alex0973    : 只是這部電影的我流設定? 01/05 23:36
# → pineapple824: 是了無「新」意 01/07 02:30
# 推 hp4935      : 嘉文好像是虛構的，女童院出身從小懂得善用身材優 01/07 13:05
# → hp4935      : 勢的人設，但沒拍出來，或者沒播出來，角色就單薄了 01/07 13:05
# → hp4935      : 許多 01/07 13:05
